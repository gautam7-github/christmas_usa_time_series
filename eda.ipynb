# %%
import pandas as pd
df = pd.read_excel(
    'https://query.data.world/s/3giyp5lgkomz2ap3yhss6bxvkox2mk',
    engine='openpyxl'
    )

# %%
df.to_csv("data.csv",index=False)

# %%
df.head()
# Out:
#    Year  Gifts for Family  Gifts for Friends  Gifts for Coworkers  Other Gifts
# 0  2004               405                 71                   22           41
# 1  2005               419                 79                   21           44
# 2  2006               428                 81                   21           42
# 3  2007               434                 83                   21           35
# 4  2008               389                 79                   22           36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 18 non-null     int64
#  1   Gifts for Family     18 non-null     int64
#  2   Gifts for Friends    18 non-null     int64
#  3   Gifts for Coworkers  18 non-null     int64
#  4   Other Gifts          18 non-null     int64
# dtypes: int64(5)
# memory usage: 848.0 bytes

# %%
df['Total'] = df.iloc[:,1:].sum(axis=1)

# %%
df.to_csv("data-totaled.csv",index=False)

# %%
df.drop("Total",axis=1).plot.line(x='Year')
# Out:
# <AxesSubplot: xlabel='Year'>
